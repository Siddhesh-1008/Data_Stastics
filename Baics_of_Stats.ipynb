# %%
# ONE WAY TABLE IN WHICH VARIBALE DEPENDENT ON ONE INDIVIDUAL
MEANS AGE SALARY(VARIABLES) IS DEPENDENT ON PERSONS NAME(INDIVIDUAL)

# %%
1. Quantitative Variables (Numerical Data)
These are values that can be measured or counted and mathematical operations can be performed on them.
2. Qualitative Variables (Categorical Data)
These describe categories or labels, not numerical measurements.

# %% [markdown]
# # A pie chart is used to show the percentage contribution of each category to the total dataset.
#     The percentage is calculated as:
# (Category Count / Total Count) × 100
#
# Bar Chart → Compare counts
# Pie Chart → Compare percentages

# %% [markdown]
# # When should we use a Bar Graph and when should we use a Line Graph?
# 📈 Line Graph
# Use when data changes over time or follows a sequence/trend.
# ✅ Best for:
# Stock prices
# Temperature changes
# Monthly sales
# Population growth
# Website traffic
#
#
# 📊 Bar Graph
# Use when comparing different categories.
# ✅ Best for:
# Team wins
# Students per branch
# Product sales comparison
# Country population comparis
#
#
#
# If X-axis is Time
# Jan → Feb → Mar → Apr
# 2020 → 2021 → 2022
# ➡️ Use Line Graph
#
# If X-axis is Categories
# CSE
# ECE
# MECH
# or
# Apple
# Banana
# Mango
# ➡️ Use Bar Graph

# %% [markdown]
# # What is an Ogive?
# An Ogive is a graph of cumulative frequency.
# Instead of plotting original values, we keep adding previous values.
#
# It is used to determine medians, percentiles, quartiles, and running totals.

# %%
IN ONE WAY->WEDEPENDEENT ON ONE CATEGORIAL VARIABLE
IN TWO WAY->WE DEPENDENT ON TWO CATEGORIAL VARIABLE


ONE WAY TABLE
Question:
Kitne Male aur Female hai?
Hum sirf Gender dekh rahe hain.
Count:
Gender	Count
Male	3
Female	2
Ye One-Way Table hai.

TWO WAY TABLE
Ab question badal gaya:
Kitne Male CSE me?
Kitne Male ECE me?
Kitni Female CSE me?
Kitni Female ECE me?

Ab hume Gender + Branch dono dekhna padega.
Table:
Gender	CSE	ECE
Male	2	1
Female	1	1

Ye Two-Way Table hai.

# %% [markdown]
# # RELATIVE FREQUECNY TABLE
# Relative Frequency =
# Frequency / Total Observations
#
# Relative Frequency Table
# Fruit	Frequency	Relative Frequency
# Apple	5	           0.50
# Banana	3	           0.30
# Mango	2	           0.20
#
# Kya Bata Raha Hai?
# Frequency batata hai:
# Apple kitni baar aaya?
# → 5
# Relative Frequency batata hai:
# Total ka kitna hissa Apple hai?
# → 50%
#
#
# Frequency:
# Apple = 5 students
#
# Relative Frequency:
# Apple = 0.5 of class
# Percentage:
# Apple = 50% of class

# %% [markdown]
# # Joint Distribution Table
# Two-Way Table showing counts/frequencies

# %% [markdown]
# # BAR CHART
# Teacher ne students ke gym hours likhe:
# 3,4,4,5,5,5,6,6,7,8,9,10,10,10,10,11,11,12,13,14,15,15,18,18,20,20,20,21,24,24
#
# Ab problem 👇
# Step 1: Find Range
# Formula:
# Range = Maximum - Minimum
# Yaha:
# Maximum = 24
# Minimum = 3
# So:
# 24 - 3 = 21
# Range = 21
#
# STEP2:-create bins
# Teacher ne bola:
# 6 bins banate hain
# Bin Width:
# 21 / 6 = 3.5
#
#
# Step 3: Create Intervals
# Har bin width = 4
# 1-5
# 5-9
# 9-13
# 13-17
# 17-21
# 21-25
# Ye bins hain.
#
# STEP4:THEN SEE THE TABLE AND BASED ON THE RANGE PLOT VALUES IF INOUT IS 3,4,2, THEN IT WILL COME IN BIN

# %% [markdown]
# # 5 NUMBER SUMMARY
# It gives complete information about:
# Center of data
# Spread of data
# Outliers
# Distribution
# without showing all observations.
#
# # IT IS USED TO CREATE A BOX PLOT OUTLIER IS SHOWN WITH THE HELP OF DIAMOND SYMBOL
# # Step 1: Minimum
# Sabse chhota value
# 10
#
# # Step 2: Q1 (25%)
# 10,20,30,40
# Middle:
# (20+30)/2 = 25
# Q1 = 25
#
# # Step 3: Median (50%)
# 10,20,30,40,50,60,70,80,90
# Median = 50
#
# # Step 4: Q3 (75%)
# Upper half:
# 60,70,80,90
# Middle:
# (70+80)/2 = 75
# Q3 = 75
#
# # Step 5: Maximum
# Largest value
# 90

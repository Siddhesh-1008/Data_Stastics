# %% [markdown]
# # COVARIANCE JUST TELL U THE RELATIONSHIP BETWEEN TWO VARIBALES WHETHER IT IS POSIITIVE OR ENGATIVE
# # Positive Covariance
# X ↑ Y ↑
# or
# X ↓Y ↓
#
# # Negative Covariance
# X ↑Y ↓
# or
# X ↓Y ↑
# # Zero Covariance
# No relationship
# eg:-no of hours and marks relation more hours study more maks Positive covariance
# no of hours and marks relation more hours study less maks Negative covariance
#
# # Problem with Covariance 😭
# Covariance bolta hai:Positive relation,Negative relation
# But ye nahi batata:Kitna strong relation hai

# %%
from IPython.display import Image, display
display(Image(filename='Covariance.png'))

# %% [markdown]
# # Correlation
# Correlation measuresstrength and direction of relationship between two variables.

# %%
Example
Hours Studied	Marks
1	40
2	50
3	60
4	70

Perfect relation.
Correlation:+1

Range−1≤r≤1

r = +1
Perfect Positive
Hours ↑Marks ↑

r = -1
Perfect Negative
Temperature ↑
Jacket Sales ↓

r = 0
No Linear Relationship

# %%
display(Image(filename='Correlation.png'))

# %% [markdown]
# # Chi-Square Test
# Chi-Square Test checks whether there is a relationship between categorical variables
# or whether observed data differs from expected data.
# EG:-Gender and Product Purchase related hain kya?

# %%
display(Image(filename='Chisqr_Test2.png'))

# %%
from IPython.display import Image, display
display(Image(filename='Chisqr_Test.png'))

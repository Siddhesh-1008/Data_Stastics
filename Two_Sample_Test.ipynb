# %% [markdown]
# # TWO SAMPLE TEST
# # TWO SAMPLE TEST USED WHEN WE ARE COMPARING TWO SAMPLE MEANS

# %% [markdown]
# # Two Sample Z-Test
# When comparing two sample means and the population standard deviations are known.
# Population SD Known?
#
# # Two Sample T-Test
# When comparing two sample means and the population standard deviations are unknown.
# In this case we use sample standard deviations.
#
# Population SD Known?
# YES
#  ↓
# Z-Test
#
# NO
#  ↓
# T-Test

# %%
from IPython.display import Image, display
display(Image(filename='TWO_SAMPLE_TEST_SUM1.png'))
